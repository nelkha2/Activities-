# %%
# Create code to answer each of the following questions.
# Hint: You will need multiple target URLs and multiple API requests.

# Dependencies
import requests
import json

# Retrieve Google API key from config.py
from config import gkey

# %%
# 1. What are the geocoordinates (latitude and longitude) of Seattle,
# Washington?
target_city = "Seattle, Washington"
params = {"address": target_city, "key": gkey}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

print("Drill #1: The Geocoordinates of Seattle, WA")

# Run request
response = requests.get(base_url, params=params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)

# Convert to JSON
seattle_geo = response.json()

# Extract lat/lng
lat = seattle_geo["results"][0]["geometry"]["location"]["lat"]
lng = seattle_geo["results"][0]["geometry"]["location"]["lng"]

# Print results
print(f"{target_city}: {lat}, {lng}")
# Out:
# Drill #1: The Geocoordinates of Seattle, WA
# Seattle, Washington: 47.6062095, -122.3320708

# %%
# 3. Find the name and address of a bike store in Seattle, Washington.
#    Hint: See https://developers.google.com/places/web-service/supported_types

target_coordinates = "47.6062095, -122.3320708"
target_radius = 8000
target_type = "bicycle_store"

params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

bike_data = response.json()
#print(json.dumps(bike_data, indent=4, sort_keys=True))

bike_name = bike_data["results"][0]["name"]
bike_data["results"][0]["vicinity"]
# Out:
# '222 Yale Avenue North, Seattle'

# %%
# 4. Find a balloon store near the White House.

# %%
# 5. Find the nearest dentist to your house.
#    Hint: Use Google Maps to find your latitude and Google Places to find the
#    dentist. You will also need the rankby property.

# %%
# 6. Bonus: Find the names and addresses of the top five restaurants in your home city.
#    Hint: Read about "Text Search Results"
# (https://developers.google.com/places/web-service/search#TextSearchRequests)
my_phrase = "best restaurant in Washington, DC"
target_url = "https://maps.googleapis.com/maps/api/place/textsearch/json"

params = {
    "query": my_phrase,
    "key": gkey
}

print("Drill #6: Bonus")

response = requests.get(target_url, params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
# print(response.url)
happy_places = response.json()
# print(json.dumps(happy_places, indent=4, sort_keys=True))

counter = 0

for place in happy_places["results"]:
    #print(place["name"])
    #print(place["formatted_address"])
    counter += 1
    if counter == 5:
        break
happy_places
# Out:
# Drill #6: Bonus
# {'html_attributions': [],
#  'next_page_token': 'CpQCEAEAAPG5VTTOimECn9g89gsbJ-dpNU6MjCo1wJj2xTZwviBk2aVOemiDk-aRIbhKE74T2d-zNo4faNFwT8cWyS-dgnXdW2603_zxgAtl2V2RYRW1ULJnQzPQ1t8-I1_JBmbfsYTZ3YEEYtVTbL44ivTfYLE316B3GSay1iMp_6482yK-q1F6VyY8SlCz0rCehhB80p1dut-Tn-ZVSKuFvavNJKVY1E_YEyC4DXRslpIOJRHkVeGEeiWHCkV_yA-KNJRz7UUNDBK6H2H-vHlfj4TgJNB5bl-iDb05569O75lsg89n9HZdvKez86CjkUTxqISuKS0e7e1s4epS54bSYXhqhdEKsv4q9WLz6iChangRHYD0EhCpK7kIelo9sv36DSW1XFxJGhRhwsenFgMZYq_SKwI6YMvw5imB3w',
#  'results': [{'formatted_address': '701 9th St NW, Washington, DC 20001, USA',
#    'geometry': {'location': {'lat': 38.8987445, 'lng': -77.023684},
#     'viewport': {'northeast': {'lat': 38.90003892989272,
#       'lng': -77.02248917010729},
#      'southwest': {'lat': 38.89733927010727, 'lng': -77.02518882989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'd2f9226313468e088cfb1efe9b91e3888e18c181',
#    'name': 'Zaytinya',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113294694364441671590/photos">King Bob</a>'],
#      'photo_reference': 'CmRaAAAANfV24UIgOCGFxrFRsUIfq-ss8krZzIE2nD6JFSChKS8654UpI1ssE2EVIl1vo5IhwjenPx-hN1SRkrxSWNIFLyy6OdvmTgBO4xtWc_EbTorC-6bz_0jZfIct6gQTYQi-EhBfucU5zQQD7pRBV_OnFYEoGhSxWJmIAmNlZWXXxNU2cMz6H_j0Bg',
#      'width': 3840}],
#    'place_id': 'ChIJ3_mSkpG3t4kRDEWpol01OrI',
#    'plus_code': {'compound_code': 'VXXG+FG Washington, District of Columbia, USA',
#     'global_code': '87C4VXXG+FG'},
#    'price_level': 3,
#    'rating': 4.5,
#    'reference': 'ChIJ3_mSkpG3t4kRDEWpol01OrI',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 3356},
#   {'formatted_address': '675 15th St NW, Washington, DC 20005, USA',
#    'geometry': {'location': {'lat': 38.897954, 'lng': -77.0333395},
#     'viewport': {'northeast': {'lat': 38.89934997989272,
#       'lng': -77.03216057010728},
#      'southwest': {'lat': 38.89665032010728, 'lng': -77.03486022989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '7fe59b69ed22ba94e6101f5a7e838b4cf4588ef9',
#    'name': 'Old Ebbitt Grill',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 750,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111419326936123221540/photos">Keith Cross</a>'],
#      'photo_reference': 'CmRaAAAAb4IJfZePVGluhtvGOtlLHvOd9-YIdrWjKZ3o1gK_U7QLCis1sEqWimi4f68pO7PZiIOR8qnFGhlrzGdOtoydBKgshMqtPrs1x9n_6ymo7yB77zMMfcaw4o5YzQxJU2hcEhBMbMCNSdZ4Cvxvv_Jm60sTGhQ58iD0I1sn41A8LvxQy9qgdFnc4w',
#      'width': 1000}],
#    'place_id': 'ChIJgRwXf723t4kRdfqt36VafUU',
#    'plus_code': {'compound_code': 'VXX8+5M Washington, District of Columbia, USA',
#     'global_code': '87C4VXX8+5M'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJgRwXf723t4kRdfqt36VafUU',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 8373},
#   {'formatted_address': '1443 P St NW, Washington, DC 20005, USA',
#    'geometry': {'location': {'lat': 38.9098773, 'lng': -77.0334769},
#     'viewport': {'northeast': {'lat': 38.91111472989272,
#       'lng': -77.03212717010727},
#      'southwest': {'lat': 38.90841507010727, 'lng': -77.03482682989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '8bb6c452e1288bfbfa09b925b3c218e0cd63533c',
#    'name': 'Commissary',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3036,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112367715960341876157/photos">R W</a>'],
#      'photo_reference': 'CmRaAAAAVsBE0I0QSKQMFn0IdjLzIB900q7IUjumxRipCmFiul_ZCER2W69805vtrRK87alt587gq_ED5eqPC7Yb10EmA_bZrIzIyppBAf4qZRcSbsPtYvUVTwttXlV4GUXQBQxAEhC1Bf3S_FJR0KX2Shvcb4YfGhRD6H0D-2iC60NrM7PHFa7arXbjIQ',
#      'width': 4048}],
#    'place_id': 'ChIJ_2_y38G3t4kR_VnOXAMdT80',
#    'plus_code': {'compound_code': 'WX58+XJ Washington, District of Columbia, USA',
#     'global_code': '87C4WX58+XJ'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJ_2_y38G3t4kR_VnOXAMdT80',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 868},
#   {'formatted_address': '2441 18th St NW, Washington, DC 20009, USA',
#    'geometry': {'location': {'lat': 38.9216035, 'lng': -77.04200829999999},
#     'viewport': {'northeast': {'lat': 38.92292037989272,
#       'lng': -77.04081332010728},
#      'southwest': {'lat': 38.92022072010727, 'lng': -77.04351297989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '91a26aef1f969fa1768ef6451dfc02e8c25baa55',
#    'name': 'Sakuramen Ramen Bar',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113357316050600591318/photos">Michael Weingartner</a>'],
#      'photo_reference': 'CmRaAAAAoOljw9ouDp5ZmqWk-5j5BynC9po5vINDR2y7oUHu-RQx7iVUvncwKZ-0piGfpavbpMJaW3vydx7YxLv54q4IMlNIA9nlLicLa4fN8tyx0HlGnBFEnDMcDBgCt6j8goFnEhBGTvY9jqPs-HbHPAcUnp3LGhRY1rNgURdjQfxrt1Nyk0Veb5Y6kw',
#      'width': 1080}],
#    'place_id': 'ChIJd_4eM9q3t4kRL3wpwXbtIug',
#    'plus_code': {'compound_code': 'WXC5+J5 Washington, District of Columbia, USA',
#     'global_code': '87C4WXC5+J5'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJd_4eM9q3t4kRL3wpwXbtIug',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 828},
#   {'formatted_address': '1924 Pennsylvania Ave NW, Washington, DC 20006, USA',
#    'geometry': {'location': {'lat': 38.9002854, 'lng': -77.0445269},
#     'viewport': {'northeast': {'lat': 38.90177762989273,
#       'lng': -77.04315832010728},
#      'southwest': {'lat': 38.89907797010728, 'lng': -77.04585797989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '5a4d05c77924c28434321589acdeefacbfee8c9f',
#    'name': 'Founding Farmers DC',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1536,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107222926279340248734/photos">Valerie Paxton</a>'],
#      'photo_reference': 'CmRaAAAANh5qHz62B_ZOd-PNo6h6CfMePej1w74JGHHmL1MV_nWQKzX0IKEqDzjR5TMJ-L5vx5qej_dC7ov7FA1yzVagvjUGlQ7SVcvFdBYNVAunEtpPvIiqZTbstVqTT4vPvh3TEhBLvmIK-FCqbOPEP1o764n9GhTy1HQjwxlwjyGxQTMg_XS7LCcqjA',
#      'width': 2048}],
#    'place_id': 'ChIJk58zcbq3t4kR9VDFZdcB5uE',
#    'plus_code': {'compound_code': 'WX24+45 Washington, District of Columbia, USA',
#     'global_code': '87C4WX24+45'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJk58zcbq3t4kR9VDFZdcB5uE',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 7695},
#   {'formatted_address': '1601 14th St NW, Washington, DC 20009, USA',
#    'geometry': {'location': {'lat': 38.9113639, 'lng': -77.0315724},
#     'viewport': {'northeast': {'lat': 38.91273227989272,
#       'lng': -77.03041037010728},
#      'southwest': {'lat': 38.91003262010728, 'lng': -77.03311002989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '59313e3b719330313ffb0f8165cf12181a4c761e',
#    'name': 'Le Diplomate',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 673,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105303505373661530610/photos">A Google User</a>'],
#      'photo_reference': 'CmRaAAAAtPyiHSy8swZ2OIGNtW8iP3PeCc4hexDYrx64FSbuNRXO63qzyi4WwkFBWQSne15N8-oLokDBf4w8cAKX3OBIVS8QkG3dWV6JG8Sc2aC6HAba70I1BiU1x_BQwq-EBRKrEhA9Zvv5Hdae0j9qjVlLhgO4GhQzpTSrfH2O7CpNja34eM8PyYvdew',
#      'width': 1000}],
#    'place_id': 'ChIJgYIki-m3t4kRZImvuN_pp9Q',
#    'plus_code': {'compound_code': 'WX69+G9 Washington, District of Columbia, USA',
#     'global_code': '87C4WX69+G9'},
#    'price_level': 3,
#    'rating': 4.6,
#    'reference': 'ChIJgYIki-m3t4kRZImvuN_pp9Q',
#    'types': ['bar',
#     'cafe',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 2678},
#   {'formatted_address': '(entrance on Indiana Ave), 601 Pennsylvania Avenue Northwest, Washington, DC 20004, United States',
#    'geometry': {'location': {'lat': 38.89381300000001, 'lng': -77.020546},
#     'viewport': {'northeast': {'lat': 38.89534767989272,
#       'lng': -77.01935807010729},
#      'southwest': {'lat': 38.89264802010728, 'lng': -77.02205772989274}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '5bd5f21ffb81c6c63ddcd0aa406638e07f5560f3',
#    'name': 'Fiola',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1211,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109648611401468538572/photos">Fiola</a>'],
#      'photo_reference': 'CmRZAAAA4cGbvQcwZgU1wHlbPf5jTt1U3uoxsBztwYjnpq53RwgwUlUOdHeby1Bg-1qolAZLAS9AjDPGuT-ONQcKKFZU6f7KYpRnDoZ2nlJoq6Xn-XoavBK0CPAcJ6tvwsQ6ATiyEhA_Q01kWRsSUsedynJwBhYVGhSEI-iNYuXraDmASN1ZrPautBD2Lw',
#      'width': 1800}],
#    'place_id': 'ChIJJT16aoW3t4kRuvr4twwPMFY',
#    'plus_code': {'compound_code': 'VXVH+GQ Washington, District of Columbia, USA',
#     'global_code': '87C4VXVH+GQ'},
#    'price_level': 4,
#    'rating': 4.6,
#    'reference': 'ChIJJT16aoW3t4kRuvr4twwPMFY',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 439},
#   {'formatted_address': '1200 New Hampshire Ave NW, Washington, DC 20036, USA',
#    'geometry': {'location': {'lat': 38.9057285, 'lng': -77.04772},
#     'viewport': {'northeast': {'lat': 38.90697337989272,
#       'lng': -77.04616187010727},
#      'southwest': {'lat': 38.90427372010728, 'lng': -77.04886152989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '5dd041a4806d454a912b1bd77af93da9250dc649',
#    'name': 'Grillfish',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3232,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100209535546317234989/photos">Milly Hall</a>'],
#      'photo_reference': 'CmRaAAAAjViKlHrD-MzlbUoxz60bFzjepQHADUZHXyj26Fa37TytXjajOhLDsbEjoFpxVGC-c4fc0NzYpR6PfOYukMeE_ln9WQDgqHYjRP8iDKxCfHGdF2EeWVnrAYn6xb8dfUMDEhCsWemFxGVagsbOgOzpTCEHGhSPO4c0NSEYzTG8Pz6JnBI-81UwVg',
#      'width': 2424}],
#    'place_id': 'ChIJgyFWsre3t4kRfe4CuUyQ7Lo',
#    'plus_code': {'compound_code': 'WX42+7W Washington, District of Columbia, USA',
#     'global_code': '87C4WX42+7W'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJgyFWsre3t4kRfe4CuUyQ7Lo',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 538},
#   {'formatted_address': '1423 P St NW, Washington, DC 20005, USA',
#    'geometry': {'location': {'lat': 38.9097932, 'lng': -77.0327981},
#     'viewport': {'northeast': {'lat': 38.91107247989272,
#       'lng': -77.03144747010728},
#      'southwest': {'lat': 38.90837282010727, 'lng': -77.03414712989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '4c3c7a88b9592fffd6f4e00472c432a646907b90',
#    'name': 'Logan Tavern',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103340774085618297578/photos">Denia Murillo</a>'],
#      'photo_reference': 'CmRaAAAA-gyUHPtw_spbNEaRupwKnGyBKwT_Y5fQ5vB2escONCrMzoWPTzxyC3fPmL0gZfFs3KkKqKXDdg3ksPu0YhTEGnndDwkQEYw41IV8xrJxIB6UGuVVWlSI7zn0AkRDQhVPEhAZeSnfF9rL8lmzMRetDeVzGhQPurSPtb7FnOtjcmOKKXVmZ9rQvQ',
#      'width': 4032}],
#    'place_id': 'ChIJ7eQlc-q3t4kRbcF_amuMsHM',
#    'plus_code': {'compound_code': 'WX58+WV Washington, District of Columbia, USA',
#     'global_code': '87C4WX58+WV'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJ7eQlc-q3t4kRbcF_amuMsHM',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 638},
#   {'formatted_address': '1341 G St NW, Washington, DC 20005, USA',
#    'geometry': {'location': {'lat': 38.8985773, 'lng': -77.03154359999999},
#     'viewport': {'northeast': {'lat': 38.89979687989272,
#       'lng': -77.03019532010728},
#      'southwest': {'lat': 38.89709722010727, 'lng': -77.03289497989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '3c5a32c0709e82544cc61e3e8605a4e7ad5a6f75',
#    'name': 'Ocean Prime',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3036,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107980176062249883283/photos">Courtney Morris</a>'],
#      'photo_reference': 'CmRaAAAA8b55sr1jNr8c9A0IrqtAF37z4-4S4AN_A3gDuevAY1i77K1h4QOw__yGeIddUe-5xg7yRoUqbqRMNPGIdQJlhq19OvK1C8OBIcdaKNgQdqPX7xk7xaycTL5RpV7kAOAWEhCYSjXIKG2d98aq0bJtMa_XGhTc6HMcjbgROrfY4MBTUfDagr33Bg',
#      'width': 4048}],
#    'place_id': 'ChIJ5YEiT5a3t4kRDzenVaC_5Qc',
#    'plus_code': {'compound_code': 'VXX9+C9 Washington, District of Columbia, USA',
#     'global_code': '87C4VXX9+C9'},
#    'price_level': 4,
#    'rating': 4.6,
#    'reference': 'ChIJ5YEiT5a3t4kRDzenVaC_5Qc',
#    'types': ['night_club',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 591},
#   {'formatted_address': '425 7th Street NW at, E St NW, Washington, DC 20004, United States',
#    'geometry': {'location': {'lat': 38.8956851, 'lng': -77.0217655},
#     'viewport': {'northeast': {'lat': 38.89696862989273,
#       'lng': -77.02049442010728},
#      'southwest': {'lat': 38.89426897010728, 'lng': -77.02319407989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'a93e5488acab0cda9fea47d0129ddd42f685c4f0',
#    'name': "Carmine's Italian Restaurant",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109771074614007806300/photos">Matt Durbin</a>'],
#      'photo_reference': 'CmRaAAAAtWTIFHqwA1m2m55d51JdjsCqSNQEuuSsa5NAN5sHO-bXsC9QjC3H9Q1TvYytDdSO7l5KfuYdEX3WOO3RnRxXjbAZLgAc4XaeJGHub9yUIe4fg4-cLFQJVyKP1zF9ciQLEhCHaCu9cOqFhXIDgwoIlghTGhRPVH_hKIYDnhQgq2v-aD-b-O6oxQ',
#      'width': 3024}],
#    'place_id': 'ChIJfzxy4Y-3t4kRbnTqSV0k8uA',
#    'plus_code': {'compound_code': 'VXWH+77 Washington, District of Columbia, USA',
#     'global_code': '87C4VXWH+77'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJfzxy4Y-3t4kRbnTqSV0k8uA',
#    'types': ['meal_takeaway',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 2412},
#   {'formatted_address': '1818 14th St NW, Washington, DC 20009, USA',
#    'geometry': {'location': {'lat': 38.91467129999999, 'lng': -77.0321082},
#     'viewport': {'northeast': {'lat': 38.91604837989271,
#       'lng': -77.03068062010729},
#      'southwest': {'lat': 38.91334872010727, 'lng': -77.03338027989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '6f6d349156bcc4295f2f8e1c59390e0c47b0c762',
#    'name': "Ted's Bulletin",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2218,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110452599974688077516/photos">Matt Sweetwood</a>'],
#      'photo_reference': 'CmRaAAAAlCTpS7mQdoMADe6wEWniTbEU4aPrgR73Ci8S6zmgMd1x5mmQL8D2rZrA5HcEiAmPF3ztt-s4NiDxuVHWBMwbKos1VfDrfUp7OJvKtl_jAXlO_b8diG_-wmIFO6qIDSerEhDf3rXbKS_mjQ9-z8aefj-yGhQzG_9-L9JtteDCyBF0Fjf4Ec0Jjw',
#      'width': 4656}],
#    'place_id': 'ChIJkceyP-i3t4kRISOyo8QO6Mo',
#    'plus_code': {'compound_code': 'WX79+V5 Washington, District of Columbia, USA',
#     'global_code': '87C4WX79+V5'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJkceyP-i3t4kRISOyo8QO6Mo',
#    'types': ['bar',
#     'bakery',
#     'cafe',
#     'restaurant',
#     'food',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 2219},
#   {'formatted_address': '480 7th St NW, Washington, DC 20004, USA',
#    'geometry': {'location': {'lat': 38.8959259, 'lng': -77.0222721},
#     'viewport': {'northeast': {'lat': 38.89735572989272,
#       'lng': -77.02079102010728},
#      'southwest': {'lat': 38.89465607010728, 'lng': -77.02349067989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'dffc2688d43e65a3f6830908852aa2c95314e6c9',
#    'name': 'Jaleo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3006,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101478556917217746058/photos">Andrew McMenimen</a>'],
#      'photo_reference': 'CmRaAAAAKKq_Y5RwE_B9ngrgMyJ0VDh2xIPCbGdiAuv19zPBxZ8I-QJ2tWeelz0vEnvabzfdxz1flPoRR9-qXtKsv058DJl_CgDN4P1ijeQAXkvSV7Q0fH8xdVGeE67SBe0UB5w2EhBvYIOzfI8n2491g9A_eXqjGhQ1a7evV19G0tlQgdXsPwoUdaq5Gw',
#      'width': 5344}],
#    'place_id': 'ChIJLQH_IJC3t4kRZLetUEiw_Lw',
#    'plus_code': {'compound_code': 'VXWH+93 Washington, District of Columbia, USA',
#     'global_code': '87C4VXWH+93'},
#    'price_level': 3,
#    'rating': 4.4,
#    'reference': 'ChIJLQH_IJC3t4kRZLetUEiw_Lw',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 2001},
#   {'formatted_address': '1063 Wisconsin Ave NW, Washington, DC 20007, USA',
#    'geometry': {'location': {'lat': 38.9043899, 'lng': -77.0624277},
#     'viewport': {'northeast': {'lat': 38.90577162989272,
#       'lng': -77.06126667010729},
#      'southwest': {'lat': 38.90307197010728, 'lng': -77.06396632989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '3dd5be33bb6d61ac173d188033ce60ea47e39b01',
#    'name': 'Filomena Ristorante',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1836,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102060329451736157791/photos">jasmine w</a>'],
#      'photo_reference': 'CmRaAAAAX8eXsTkt3HKL2G4di_Sle5AK9qdTqK5IxIbbFXdUYOrM2iTTdarrlA-CFcx3GMskAPMvmxBcUyj0WahHhx-o4BIhQpO5Q5vbk-6Gk8poKTuSPYWMLxPax6uy-4Fl1aVUEhACYAp3bv379tmeHCa92ynrGhQNn9dhcLiQKpkFjvtCSmEbMP_EmQ',
#      'width': 3264}],
#    'place_id': 'ChIJPTqF_Uu2t4kR9o9RyZkZPWA',
#    'plus_code': {'compound_code': 'WW3Q+Q2 Washington, District of Columbia, USA',
#     'global_code': '87C4WW3Q+Q2'},
#    'price_level': 3,
#    'rating': 4.5,
#    'reference': 'ChIJPTqF_Uu2t4kR9o9RyZkZPWA',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1942},
#   {'formatted_address': '4445 Connecticut Ave NW, Washington, DC 20008, USA',
#    'geometry': {'location': {'lat': 38.9469996, 'lng': -77.0646494},
#     'viewport': {'northeast': {'lat': 38.94825492989272,
#       'lng': -77.06349792010727},
#      'southwest': {'lat': 38.94555527010728, 'lng': -77.06619757989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'ff3b60b2393d7caf5b8754fe578fe4f593430144',
#    'name': 'Sfoglina',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115806961929796425102/photos">Ythalo Rossy Saldanha Lira</a>'],
#      'photo_reference': 'CmRaAAAArLz0CRJ07dI830CINY1odDvMCuTHQjJHGilKoJ8mme5vADy2VDL_irjeZ4kZJpxfkJMDykc8Gql30RpBZbW9qmfBzm8wdjdmNoQjwvhS1EXsXN4MiCFFIJKztSfgmsPiEhBHlSYfgNDfzzxx7txbI4VbGhS1CM2uggcOwsr_YHQ-a_4yp97d7Q',
#      'width': 1920}],
#    'place_id': 'ChIJ9ZNUIMnJt4kROSdJCiqj9Kg',
#    'plus_code': {'compound_code': 'WWWP+Q4 Washington, District of Columbia, USA',
#     'global_code': '87C4WWWP+Q4'},
#    'price_level': 3,
#    'rating': 4.6,
#    'reference': 'ChIJ9ZNUIMnJt4kROSdJCiqj9Kg',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 388},
#   {'formatted_address': '1700 K St NW, Washington, DC 20006, USA',
#    'geometry': {'location': {'lat': 38.9022216, 'lng': -77.04033319999999},
#     'viewport': {'northeast': {'lat': 38.90366432989273,
#       'lng': -77.03898242010726},
#      'southwest': {'lat': 38.90096467010729, 'lng': -77.04168207989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'fafaf0b1e8a91f01fdda684f969e0fb892f789ed',
#    'name': 'Kellari Taverna',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113661904844981593311/photos">Pat Revord</a>'],
#      'photo_reference': 'CmRaAAAAWmK7kmBT0JACNXfEOuVL7qpqyE7R9TW1w3ja058iChkw4XOvYytEATKdOOXAf0l3hJJufT7r5Kb5sTGnFY0_eV7lpjKZ94mjcwdkwLmJ4Il7xT6uJvJvm3an1T0hwWKVEhBp3Tnt8jhcQUbuUWPDs4ImGhSkoPpPDjGin_o4wfkrpI19m41TxQ',
#      'width': 5312}],
#    'place_id': 'ChIJ22FWRbm3t4kRvMYVoXKt6mI',
#    'plus_code': {'compound_code': 'WX25+VV Washington, District of Columbia, USA',
#     'global_code': '87C4WX25+VV'},
#    'price_level': 3,
#    'rating': 4.4,
#    'reference': 'ChIJ22FWRbm3t4kRvMYVoXKt6mI',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 406},
#   {'formatted_address': '1225 19th St NW, Washington, DC 20036, USA',
#    'geometry': {'location': {'lat': 38.9066664, 'lng': -77.04304359999999},
#     'viewport': {'northeast': {'lat': 38.90801762989273,
#       'lng': -77.04189442010728},
#      'southwest': {'lat': 38.90531797010728, 'lng': -77.04459407989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '31ca9440a9a588c3e6b7d2fc2d0d2e631c0484af',
#    'name': 'The Palm Washington DC',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117113235466394798666/photos">Regina L. Miles</a>'],
#      'photo_reference': 'CmRaAAAAv7qe70EpwxE3B_DT7jCu-tttwt8JMsx3k7tMKoHvrg3tddjCyIcEtoz9_JGMeCEcldb5ZcrY45_QFliHkwsD7TEK_UM3U3nnzq6YlqtmSG9PUyI9-zUqinz6lT0Cqms7EhD9iRTo3eOT2WpUmUExLtjQGhQBDHC5yRuawoAyR-f8MiliNJRcQg',
#      'width': 3024}],
#    'place_id': 'ChIJO9-Yc7i3t4kRkJ_rj1jWyN4',
#    'plus_code': {'compound_code': 'WX44+MQ Washington, District of Columbia, USA',
#     'global_code': '87C4WX44+MQ'},
#    'price_level': 4,
#    'rating': 4.4,
#    'reference': 'ChIJO9-Yc7i3t4kRkJ_rj1jWyN4',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 426},
#   {'formatted_address': '1099 New York Ave NW, Washington, DC 20001, USA',
#    'geometry': {'location': {'lat': 38.90161440000001,
#      'lng': -77.02687259999999},
#     'viewport': {'northeast': {'lat': 38.90296352989273,
#       'lng': -77.02560672010728},
#      'southwest': {'lat': 38.90026387010728, 'lng': -77.02830637989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'b2b2e15c3dddbef18e072d3ada0abbdbc8043b64',
#    'name': 'Sfoglina Downtown',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3427,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118418188481799920452/photos">Sfoglina Downtown</a>'],
#      'photo_reference': 'CmRaAAAAZEVOD50uz8zgh5dG961F_TtDnc5ImrYVXFd1JOvVjPHbFZ2OpwdlSmNL8UUf4is8vut77e5ZnkRt3GLwZxQvu071Fal0nDW-PIxFlCrD4v54Vf5l5ty9CDZg-_tK64KzEhDTCCYFDqjl_Oxb-Au54WLIGhTIkEuZ5pG1TmPqcZo7whiQfQlt5g',
#      'width': 5239}],
#    'place_id': 'ChIJGVmxk5O3t4kRHETQmsUTRYs',
#    'plus_code': {'compound_code': 'WX2F+J7 Washington, District of Columbia, USA',
#     'global_code': '87C4WX2F+J7'},
#    'price_level': 3,
#    'rating': 4.5,
#    'reference': 'ChIJGVmxk5O3t4kRHETQmsUTRYs',
#    'types': ['bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 430},
#   {'formatted_address': '791 Wharf St SW, Washington, DC 20024, USA',
#    'geometry': {'location': {'lat': 38.8789841, 'lng': -77.0247102},
#     'viewport': {'northeast': {'lat': 38.88030007989272,
#       'lng': -77.02340282010728},
#      'southwest': {'lat': 38.87760042010727, 'lng': -77.02610247989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '082773ce37085e5e91e703e9961cd9042acef0e8',
#    'name': 'Del Mar de Fabio Trabocchi',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107383391108057384377/photos">Charles Rodman</a>'],
#      'photo_reference': 'CmRaAAAArXqLC2QCYzGP-i7oQ7h8l3aZDL69EMSFVR3dDnkKgFRlQl_EYhptS2gqQ2ahN0Zmx3vh3VqT_6mOx-4zTO_S7eoXi1eu8RjvtZNAjlEK3xJQ6reniX6UT8G3-o8tr-B5EhBshQLzSxedLykQH61Ah7BLGhTC4f0uUwIgU3M-4ZBZgq7rFlHEYQ',
#      'width': 4032}],
#    'place_id': 'ChIJebQoKHG3t4kRExTKgOoqDBg',
#    'plus_code': {'compound_code': 'VXHG+H4 Washington, District of Columbia, USA',
#     'global_code': '87C4VXHG+H4'},
#    'price_level': 4,
#    'rating': 4.5,
#    'reference': 'ChIJebQoKHG3t4kRExTKgOoqDBg',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 809},
#   {'formatted_address': '974 Palmer Alley NW, Washington, DC 20001, USA',
#    'geometry': {'location': {'lat': 38.9002671, 'lng': -77.02553259999999},
#     'viewport': {'northeast': {'lat': 38.90165522989273,
#       'lng': -77.02418292010728},
#      'southwest': {'lat': 38.89895557010728, 'lng': -77.02688257989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '76fb97e04c9ab31ba3677fcb990b34deb542bb42',
#    'name': 'Centrolina',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100174197535304390472/photos">Rich Ruszkowski</a>'],
#      'photo_reference': 'CmRaAAAAg8aC961gqAlRIFSBAQh1tzTSke9C1vY8jffM6Gw7uufF7qggVX54HRn_1ik9zGfPpz1WLDCeraq3aIVQrnuCnW7NxUSIXP4yZZGVj6GPCtDGSAiTNrUm8MG0_ND-gSZhEhBPDXTwCStFZ_6D7fYxgYxHGhQT2Y5w0TRPWDKs59Ba6aeuIFI-iQ',
#      'width': 4032}],
#    'place_id': 'ChIJma782pO3t4kR-hKXI7SAq3U',
#    'plus_code': {'compound_code': 'WX2F+4Q Washington, District of Columbia, USA',
#     'global_code': '87C4WX2F+4Q'},
#    'price_level': 3,
#    'rating': 4.4,
#    'reference': 'ChIJma782pO3t4kR-hKXI7SAq3U',
#    'types': ['grocery_or_supermarket',
#     'restaurant',
#     'food',
#     'store',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 333}],
#  'status': 'OK'}
