# %%
# Import Dependencies
import numpy as np
import matplotlib.pyplot as plt

# %%
# DATASET 1
gyms = ["Crunch", "Planet Fitness", "NY Sports Club", "Rickie's Gym"]
members = [49, 92, 84, 53]
#
plt.scatter(gyms, members, marker="o", facecolors="red", edgecolors="black")
plt.title("# Gym Members")
plt.xlabel("Gym Name")
plt.ylabel("# Members")
# Out:
# Text(0, 0.5, '# Members')

# %%
plt.title("# Gym Members")
plt.xlabel("Gym Name")
plt.ylabel("# Members")
# Out:
# Text(0, 0.5, '# Members')

# %%
# DATASET 2
x_lim = 2 * np.pi
x_axis = np.arange(0, x_lim, 0.1)
sin = np.sin(x_axis)

# %%
plt.scatter(x_axis, sin, marker="o", facecolors="red", edgecolors="black",
            s=x_axis, alpha=0.75)
plt.title("sin(x)")
plt.xlabel("x")
plt.ylabel("y = sin(x)")
#Instructor 
plt.hlines(0,0,x_lim, alpha =0.5)
plt.xlim(0,x_lim)
plt.ylim(-1.25,1.25)
plt.plot(x_axis, sin, marker = 'h', color = "red", linewidth)
plt.show()
# Out:
# Text(0, 0.5, 'y = sin(x)')

# %%
# DATASET 3
gyms = ["Crunch", "Planet Fitness", "NY Sports Club", "Rickie's Gym"]
members = [49, 92, 84, 53]
x_axis = np.arange(0, len(gyms))
colors = ["yellowgreen", "red", "lightcoral", "lightskyblue"]
explode = (0, 0.05, 0, 0)

# %%
plt.title = "Gym Memberships"
plt.pie(members, explode=explode, labels=gyms, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.axis("equal")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# DATASET 4
x_axis = np.arange(0, 10, 0.1)
times = []
for x in x_axis:
    times.append(x * x + np.random.randint(0, np.ceil(max(x_axis))))

# %%
#plt.title("Scatter") - wont work with title
plt.xlabel("Length")
plt.ylabel("Time")
plt.scatter(x_axis, times, color="teal")
plt.show()
