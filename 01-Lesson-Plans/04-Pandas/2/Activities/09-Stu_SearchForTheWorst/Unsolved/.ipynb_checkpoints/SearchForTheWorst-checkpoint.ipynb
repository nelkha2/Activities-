# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# Create reference to CSV file
csv_path = "Resources/Soccer2018Data.csv"

# Import the CSV into a pandas DataFrame
soccer_2018_df = pd.read_csv(csv_path, low_memory=False)
soccer_2018_df
# Out:
#                     Name  Age          Nationality  Overall  Potential  \
# 0      Cristiano Ronaldo   32             Portugal       94         94
# 1               L. Messi   30            Argentina       93         93
# 2                 Neymar   25               Brazil       92         94
# 3              L. Suárez   30              Uruguay       92         92
# 4               M. Neuer   31              Germany       92         92
# 5         R. Lewandowski   28               Poland       91         91
# 6                 De Gea   26                Spain       90         92
# 7              E. Hazard   26              Belgium       90         91
# 8               T. Kroos   27              Germany       90         90
# 9             G. Higuaín   29            Argentina       90         90
# 10          Sergio Ramos   31                Spain       90         90
# 11          K. De Bruyne   26              Belgium       89         92
# ...

# %%
# Collect a list of all the unique values in "Preferred Position"
soccer_PP = soccer_2018_df["Preferred Position"].unique()
soccer_PP
# Out:
# array(['ST', 'RW', 'LW', 'GK', 'CDM', 'CB', 'RM', 'CM', 'LM', 'LB', 'CAM',
#        'RB', 'CF', 'RWB', 'LWB'], dtype=object)

# %%
# Looking only at strikers (ST) to start
#strikers_2018_df = soccer_2018_df.loc[soccer_2018_df["Preferred Position"] == "ST", :]
soccer_ST = soccer_2018_df.loc[soccer_2018_df["Preferred Position"] == "ST", :]
soccer_ST
# Out:
#                     Name  Age          Nationality  Overall  Potential  \
# 0      Cristiano Ronaldo   32             Portugal       94         94
# 3              L. Suárez   30              Uruguay       92         92
# 5         R. Lewandowski   28               Poland       91         91
# 9             G. Higuaín   29            Argentina       90         90
# 16             S. Agüero   29            Argentina       89         89
# 19             P. Dybala   23            Argentina       88         93
# 23         P. Aubameyang   28                Gabon       88         88
# 31        Z. Ibrahimović   35               Sweden       88         88
# 38             E. Cavani   30              Uruguay       87         87
# 46               H. Kane   23              England       86         90
# 50             R. Lukaku   24              Belgium       86         90
# 52             T. Müller   27              Germany       86         86
# ...

# %%
# Sort the DataFrame by the values in the "ST" column to find the worst
#strongest_pokemon = Pokemon_new_df.sort_values(["Power Level"], ascending=False)
worst_ST = soccer_2018_df.sort_values(["ST"])
worst_ST

# Reset the index so that the index is now based on the sorting locations
#new_index = family_and_generosity.reset_index(drop=True)
worst_ST_newindex = worst_ST.reset_index(drop =True)
worst_ST_newindex
# Out:
#                    Name  Age          Nationality  Overall  Potential  \
# 0             L. Sackey   18                Ghana       46         64
# 1            L. Polvani   22                Italy       60         71
# 2           S. O'Mahony   21  Republic of Ireland       51         59
# 3          D. Jørgensen   26              Denmark       54         59
# 4            J. McCombe   34              England       54         54
# 5          M. Rodrigues   20          Switzerland       53         62
# 6      J. Latibeaudiere   17              England       47         73
# 7               S. Bone   18              England       51         63
# 8            K. Brouder   18  Republic of Ireland       51         61
# 9          P. Kalambayi   17              England       52         66
# 10             J. Mahon   17  Republic of Ireland       50         65
# 11         Z. Al Haniti   20         Saudi Arabia       50         60
# ...

# %%
# Save all of the information collected on the worst striker
#Worst_ST = pd.DataFrame(worst_ST_newindex)
#Worst_ST
Worst_ST = worst_ST_newindex.iloc[0,:]
Worst_ST
# Out:
# Name                          L. Sackey
# Age                                  18
# Nationality                       Ghana
# Overall                              46
# Potential                            64
# Club                  Scunthorpe United
# Preferred Position                   ST
# CAM                                  29
# CB                                   45
# CDM                                  38
# CF                                   29
# CM                                   30
# LAM                                  29
# LB                                   40
# LCB                                  45
# LCM                                  30
# LDM                                  38
# LF                                   29
# LM                                   30
# LS                                   31
# LW                                   29
# LWB                                  38
# RAM                                  29
# ...
